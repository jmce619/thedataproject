# %%
# !pip install openai --upgrade

# %%
import requests
import json
import time
import os
import pandas as pd
import numpy as np
from datetime import datetime
from sentence_transformers import SentenceTransformer

# %%
LISTING_URL = f"https://www.alphavantage.co/query?function=LISTING_STATUS&apikey={ALPHA_VANTAGE_KEY}"
DESCRIPTIONS_FILE = "all_company_descriptions.json"

# Step 1: Fetch and parse ticker CSV from Alpha Vantage
if not os.path.exists("listing_status.csv"):
    print("Downloading full ticker list from Alpha Vantage...")
    response = requests.get(LISTING_URL)
    with open("listing_status.csv", "wb") as f:
        f.write(response.content)
    print("Ticker list downloaded and saved as 'listing_status.csv'.")

tickers_df = pd.read_csv("listing_status.csv")
tickers_list = tickers_df['symbol'].unique().tolist()
print(f"Total tickers to process: {len(tickers_list)}")

# Step 2: Load existing descriptions
if os.path.exists(DESCRIPTIONS_FILE):
    with open(DESCRIPTIONS_FILE, "r") as f:
        company_data = json.load(f)
    symbols_fetched = {entry['symbol'] for entry in company_data}
    print(f"Loaded {len(company_data)} previously fetched descriptions.")
else:
    company_data = []
    symbols_fetched = set()
    print("No existing descriptions found; starting fresh.")

def get_description(symbol):
    url = (
        f"https://www.alphavantage.co/query?"
        f"function=OVERVIEW&symbol={symbol}&apikey={ALPHA_VANTAGE_KEY}"
    )
    r = requests.get(url)
    if r.status_code != 200:
        print(f"HTTP Error for {symbol}: Status {r.status_code}")
        return None
    data = r.json()
    return data.get("Description", "")

# Step 3: Fetch descriptions incrementally
processed = len(symbols_fetched)
for ticker in tickers_list:
    if ticker in symbols_fetched:
        print(f"{ticker}: already fetched, skipping. ({processed}/{len(tickers_list)})")
        processed += 1
        continue

    desc = get_description(ticker)
    if desc:
        company_data.append({"symbol": ticker, "description": desc})
        print(f"{ticker}: description fetched. ({processed}/{len(tickers_list)})")
    else:
        print(f"{ticker}: no description found or API limit reached. ({processed}/{len(tickers_list)})")

    # Save progress every ticker to avoid data loss
    with open(DESCRIPTIONS_FILE, "w") as f:
        json.dump(company_data, f, indent=2)

    processed += 1
    # Alpha Vantage API rate limit: 5 calls per minute
    time.sleep(1)

print(f"\nAll descriptions fetched and saved in {DESCRIPTIONS_FILE}.")
# Out:
# Downloading full ticker list from Alpha Vantage...
# Ticker list downloaded and saved as 'listing_status.csv'.
# Total tickers to process: 11942
# No existing descriptions found; starting fresh.
# A: description fetched. (0/11942)
# AA: description fetched. (1/11942)
# AAA: no description found or API limit reached. (2/11942)
# AAAU: no description found or API limit reached. (3/11942)
# AACBR: description fetched. (4/11942)
# AACBU: no description found or API limit reached. (5/11942)
# AACG: no description found or API limit reached. (6/11942)
# AACI: no description found or API limit reached. (7/11942)
# AACIU: no description found or API limit reached. (8/11942)
# AACIW: no description found or API limit reached. (9/11942)
# AACT: no description found or API limit reached. (10/11942)
# AACT-U: no description found or API limit reached. (11/11942)
# AACT-WS: no description found or API limit reached. (12/11942)
# AADR: no description found or API limit reached. (13/11942)
# AAL: no description found or API limit reached. (14/11942)
# AALG: no description found or API limit reached. (15/11942)
# AAM: description fetched. (16/11942)
# AAM-U: no description found or API limit reached. (17/11942)
# AAM-WS: no description found or API limit reached. (18/11942)
# AAME: no description found or API limit reached. (19/11942)
# AAMI: no description found or API limit reached. (20/11942)
# AAOI: description fetched. (21/11942)
# AAON: description fetched. (22/11942)
# AAP: description fetched. (23/11942)
# AAPB: no description found or API limit reached. (24/11942)
# AAPD: no description found or API limit reached. (25/11942)
# AAPG: description fetched. (26/11942)
# AAPGV: no description found or API limit reached. (27/11942)
# AAPL: description fetched. (28/11942)
# AAPR: no description found or API limit reached. (29/11942)
# AAPU: no description found or API limit reached. (30/11942)
# AAPW: no description found or API limit reached. (31/11942)
# AAPX: no description found or API limit reached. (32/11942)
# AAPY: no description found or API limit reached. (33/11942)
# AARD: description fetched. (34/11942)
# AAT: description fetched. (35/11942)
# AAUC: description fetched. (36/11942)
# AAVM: no description found or API limit reached. (37/11942)
# AAXJ: no description found or API limit reached. (38/11942)
# AB: description fetched. (39/11942)
# ABAT: description fetched. (40/11942)
# ABBV: description fetched. (41/11942)
# ABCB: description fetched. (42/11942)
# ABCL: description fetched. (43/11942)
# ABCS: no description found or API limit reached. (44/11942)
# ABEO: no description found or API limit reached. (45/11942)
# ABEQ: no description found or API limit reached. (46/11942)
# ABEV: no description found or API limit reached. (47/11942)
# ABFL: no description found or API limit reached. (48/11942)
# ABG: no description found or API limit reached. (49/11942)
# ABI: no description found or API limit reached. (50/11942)
# ABL: no description found or API limit reached. (51/11942)
# ABLD: no description found or API limit reached. (52/11942)
# ABLG: no description found or API limit reached. (53/11942)
# ABLLL: no description found or API limit reached. (54/11942)
# ABLLW: no description found or API limit reached. (55/11942)
# ABLV: no description found or API limit reached. (56/11942)
# ABLVW: no description found or API limit reached. (57/11942)
# ABM: no description found or API limit reached. (58/11942)
# ABNB: description fetched. (59/11942)
# ABNY: no description found or API limit reached. (60/11942)
# ABOS: description fetched. (61/11942)
# ABOT: no description found or API limit reached. (62/11942)
# ABPWW: description fetched. (63/11942)
# ABR: description fetched. (64/11942)
# ABR-P-D: description fetched. (65/11942)
# ABR-P-E: description fetched. (66/11942)
# ABR-P-F: description fetched. (67/11942)
# ABSI: description fetched. (68/11942)
# ABST: no description found or API limit reached. (69/11942)
# ABT: description fetched. (70/11942)
# ABTS: description fetched. (71/11942)
# ABUS: description fetched. (72/11942)
# ABVC: description fetched. (73/11942)
# ABVE: description fetched. (74/11942)
# ABVEW: description fetched. (75/11942)
# ABVX: description fetched. (76/11942)
# ABXB: no description found or API limit reached. (77/11942)
# AC: description fetched. (78/11942)
# ACA: description fetched. (79/11942)
# ACAD: description fetched. (80/11942)
# ACB: description fetched. (81/11942)
# ACCO: description fetched. (82/11942)
# ACCS: description fetched. (83/11942)
# ACDC: description fetched. (84/11942)
# ACEL: no description found or API limit reached. (85/11942)
# ACES: no description found or API limit reached. (86/11942)
# ACET: no description found or API limit reached. (87/11942)
# ACGL: no description found or API limit reached. (88/11942)
# ACGLN: no description found or API limit reached. (89/11942)
# ACGLO: no description found or API limit reached. (90/11942)
# ACGR: no description found or API limit reached. (91/11942)
# ACHC: description fetched. (92/11942)
# ACHL: no description found or API limit reached. (93/11942)
# ACHR: description fetched. (94/11942)
# ACHR-WS: description fetched. (95/11942)
# ACHV: description fetched. (96/11942)
# ACI: description fetched. (97/11942)
# ACIC: description fetched. (98/11942)
# ACIO: no description found or API limit reached. (99/11942)
# ACIU: description fetched. (100/11942)
# ACIW: description fetched. (101/11942)
# ACLC: no description found or API limit reached. (102/11942)
# ACLO: no description found or API limit reached. (103/11942)
# ACLS: description fetched. (104/11942)
# ACLX: description fetched. (105/11942)
# ACM: description fetched. (106/11942)
# ACMR: description fetched. (107/11942)
# ACN: description fetched. (108/11942)
# ACNB: description fetched. (109/11942)
# ACNT: description fetched. (110/11942)
# ACOG: description fetched. (111/11942)
# ACON: description fetched. (112/11942)
# ACONW: no description found or API limit reached. (113/11942)
# ACP: no description found or API limit reached. (114/11942)
# ACP-P-A: no description found or API limit reached. (115/11942)
# ACR: no description found or API limit reached. (116/11942)
# ACR-P-C: description fetched. (117/11942)
# ACR-P-D: description fetched. (118/11942)
# ACRE: no description found or API limit reached. (119/11942)
# ACRS: no description found or API limit reached. (120/11942)
# ACRV: no description found or API limit reached. (121/11942)
# ACSI: no description found or API limit reached. (122/11942)
# ACST: no description found or API limit reached. (123/11942)
# ACT: no description found or API limit reached. (124/11942)
# ACTG: description fetched. (125/11942)
# ACTU: description fetched. (126/11942)
# ACTV: no description found or API limit reached. (127/11942)
# ACU: description fetched. (128/11942)
# ACV: no description found or API limit reached. (129/11942)
# ACVA: description fetched. (130/11942)
# ACVF: no description found or API limit reached. (131/11942)
# ACVT: no description found or API limit reached. (132/11942)
# ACWI: no description found or API limit reached. (133/11942)
# ACWV: no description found or API limit reached. (134/11942)
# ACWX: no description found or API limit reached. (135/11942)
# ACXP: description fetched. (136/11942)
# ADAG: description fetched. (137/11942)
# ADAL: no description found or API limit reached. (138/11942)
# ADALU: no description found or API limit reached. (139/11942)
# ADALW: no description found or API limit reached. (140/11942)
# ADAP: description fetched. (141/11942)
# ADBE: description fetched. (142/11942)
# ADBG: no description found or API limit reached. (143/11942)
# ADC: description fetched. (144/11942)
# ADC-P-A: description fetched. (145/11942)
# ADCT: description fetched. (146/11942)
# ADD: description fetched. (147/11942)
# ADEA: description fetched. (148/11942)
# ADFI: no description found or API limit reached. (149/11942)
# ADGM: description fetched. (150/11942)
# ADI: description fetched. (151/11942)
# ADIL: no description found or API limit reached. (152/11942)
# ADIV: no description found or API limit reached. (153/11942)
# ADM: description fetched. (154/11942)
# ADMA: no description found or API limit reached. (155/11942)
# ADME: no description found or API limit reached. (156/11942)
# ADN: no description found or API limit reached. (157/11942)
# ADNT: description fetched. (158/11942)
# ADNWW: no description found or API limit reached. (159/11942)
# ADOCR: no description found or API limit reached. (160/11942)
# ADP: description fetched. (161/11942)
# ADPT: no description found or API limit reached. (162/11942)
# ADPV: no description found or API limit reached. (163/11942)
# ADSE: no description found or API limit reached. (164/11942)
# ADSEW: no description found or API limit reached. (165/11942)
# ADSK: description fetched. (166/11942)
# ADT: description fetched. (167/11942)
# ADTN: description fetched. (168/11942)
# ADTX: description fetched. (169/11942)
# ADUS: description fetched. (170/11942)
# ADV: description fetched. (171/11942)
# ADVB: description fetched. (172/11942)
# ADVE: no description found or API limit reached. (173/11942)
# ADVM: description fetched. (174/11942)
# ADX: no description found or API limit reached. (175/11942)
# ADXN: description fetched. (176/11942)
# AEBI: no description found or API limit reached. (177/11942)
# AEBIV: no description found or API limit reached. (178/11942)
# AEE: description fetched. (179/11942)
# AEF: no description found or API limit reached. (180/11942)
# AEFC: description fetched. (181/11942)
# AEG: description fetched. (182/11942)
# AEHA: no description found or API limit reached. (183/11942)
# AEHL: description fetched. (184/11942)
# AEHR: description fetched. (185/11942)
# AEI: description fetched. (186/11942)
# AEIS: description fetched. (187/11942)
# AEM: description fetched. (188/11942)
# AEMD: description fetched. (189/11942)
# AEMS: no description found or API limit reached. (190/11942)
# AENT: no description found or API limit reached. (191/11942)
# AENTW: no description found or API limit reached. (192/11942)
# AEO: description fetched. (193/11942)
# AEON: no description found or API limit reached. (194/11942)
# AEP: description fetched. (195/11942)
# AEPPZ: no description found or API limit reached. (196/11942)
# AER: no description found or API limit reached. (197/11942)
# AERT: no description found or API limit reached. (198/11942)
# AERTW: no description found or API limit reached. (199/11942)
# AES: no description found or API limit reached. (200/11942)
# AESI: description fetched. (201/11942)
# AESR: no description found or API limit reached. (202/11942)
# AETH: no description found or API limit reached. (203/11942)
# AEVA: description fetched. (204/11942)
# AEVAW: description fetched. (205/11942)
# AEYE: description fetched. (206/11942)
# AFB: no description found or API limit reached. (207/11942)
# AFBI: description fetched. (208/11942)
# AFCG: description fetched. (209/11942)
# AFG: description fetched. (210/11942)
# AFGB: description fetched. (211/11942)
# AFGC: description fetched. (212/11942)
# AFGD: description fetched. (213/11942)
# AFGE: description fetched. (214/11942)
# AFIF: no description found or API limit reached. (215/11942)
# AFIX: no description found or API limit reached. (216/11942)
# AFJK: description fetched. (217/11942)
# AFJKR: description fetched. (218/11942)
# AFJKU: description fetched. (219/11942)
# AFK: no description found or API limit reached. (220/11942)
# AFL: description fetched. (221/11942)
# AFLG: no description found or API limit reached. (222/11942)
# AFMC: no description found or API limit reached. (223/11942)
# AFMD: no description found or API limit reached. (224/11942)
# AFRI: no description found or API limit reached. (225/11942)
# AFRIW: no description found or API limit reached. (226/11942)
# AFRM: no description found or API limit reached. (227/11942)
# AFSC: no description found or API limit reached. (228/11942)
# AFSM: no description found or API limit reached. (229/11942)
# AFT: no description found or API limit reached. (230/11942)
# AFYA: no description found or API limit reached. (231/11942)
# AG: no description found or API limit reached. (232/11942)
# AGAE: no description found or API limit reached. (233/11942)
# AGCO: no description found or API limit reached. (234/11942)
# AGD: no description found or API limit reached. (235/11942)
# AGEM: no description found or API limit reached. (236/11942)
# AGEN: no description found or API limit reached. (237/11942)
# AGFS: no description found or API limit reached. (238/11942)
# AGFY: description fetched. (239/11942)
# AGG: no description found or API limit reached. (240/11942)
# AGGA: no description found or API limit reached. (241/11942)
# AGGH: no description found or API limit reached. (242/11942)
# AGGS: no description found or API limit reached. (243/11942)
# AGGY: no description found or API limit reached. (244/11942)
# AGH: description fetched. (245/11942)
# AGI: description fetched. (246/11942)
# AGIH: no description found or API limit reached. (247/11942)
# AGIO: description fetched. (248/11942)
# AGIX: no description found or API limit reached. (249/11942)
# AGL: description fetched. (250/11942)
# AGM: description fetched. (251/11942)
# AGM-A: description fetched. (252/11942)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 47
#      44     processed += 1
#      45     continue
# ---> 47 desc = get_description(ticker)
#      48 if desc:
#      49     company_data.append({"symbol": ticker, "description": desc})
#
# Cell In[7], line 32, in get_description(symbol)
#      27 def get_description(symbol):
#      28     url = (
#      29         f"https://www.alphavantage.co/query?"
#      30         f"function=OVERVIEW&symbol={symbol}&apikey={ALPHA_VANTAGE_KEY}"
#      31     )
# ---> 32     r = requests.get(url)
#      33     if r.status_code != 200:
#      34         print(f"HTTP Error for {symbol}: Status {r.status_code}")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import requests
import json
import time
import numpy as np
import os
from sentence_transformers import SentenceTransformer


ALPHA_VANTAGE_KEY = "60G1A3ENUDKBDCO1"
TICKERS = [
    "AAPL", "MSFT", "GOOGL", "AMZN", "TSLA", 
    "NVDA", "META", "NFLX", "INTC", "AMD"
]

DESCRIPTIONS_FILE = "company_descriptions.json"
EMBEDDINGS_FILE = "company_embeddings.json"

# Load existing descriptions if available
if os.path.exists(DESCRIPTIONS_FILE):
    with open(DESCRIPTIONS_FILE, "r") as f:
        company_data = json.load(f)
    symbols_fetched = {entry['symbol'] for entry in company_data}
    print(f"Loaded {len(company_data)} existing company descriptions.")
else:
    company_data = []
    symbols_fetched = set()
    print("No existing descriptions found; starting fresh.")

def get_description(symbol):
    url = (
        f"https://www.alphavantage.co/query?"
        f"function=OVERVIEW&symbol={symbol}&apikey={ALPHA_VANTAGE_KEY}"
    )
    print(f"Fetching description for {symbol}...")
    r = requests.get(url)
    if r.status_code != 200:
        print(f"Failed to fetch {symbol}: HTTP {r.status_code}")
        return None
    data = r.json()
    desc = data.get("Description", "")
    if not desc:
        print(f"No description found for {symbol}!")
    else:
        print(f"Description for {symbol}: {desc[:75]}...")
    return desc

# Fetch descriptions incrementally
for ticker in TICKERS:
    if ticker in symbols_fetched:
        print(f"Description for {ticker} already exists, skipping.")
        continue
    desc = get_description(ticker)
    if desc:
        company_data.append({"symbol": ticker, "description": desc})
        # Save after each description fetched
        with open(DESCRIPTIONS_FILE, "w") as f:
            json.dump(company_data, f, indent=2)
        print(f"Saved description for {ticker}.\n")
    time.sleep(15)  # Alpha Vantage free API limit (5 calls per minute)

# Initialize sentence-transformers model
print("\nLoading embedding model...")
model = SentenceTransformer('all-MiniLM-L6-v2')
print("Embedding model loaded.\n")

# Generate embeddings
embeddings_data = []
for company in company_data:
    desc = company["description"]
    print(f"Embedding description for {company['symbol']}...")
    embedding = model.encode(desc).tolist()
    embeddings_data.append({
        "symbol": company["symbol"],
        "description": desc,
        "embedding": embedding
    })

# Save embeddings
with open(EMBEDDINGS_FILE, "w") as f:
    json.dump(embeddings_data, f, indent=2)
print(f"\nSaved embeddings for {len(embeddings_data)} companies to {EMBEDDINGS_FILE}.\n")

# Similarity function (cosine similarity)
def cosine_similarity(v1, v2):
    v1 = np.array(v1)
    v2 = np.array(v2)
    return np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))

# Function to find similar companies
def find_similar(symbol, top_n=3):
    print(f"\nFinding top {top_n} companies similar to {symbol}...\n")
    with open(EMBEDDINGS_FILE, "r") as f:
        data = json.load(f)

    target = next((item for item in data if item["symbol"] == symbol), None)
    if not target:
        print(f"No embedding found for {symbol}.")
        return

    similarities = []
    for company in data:
        if company["symbol"] == symbol:
            continue
        similarity = cosine_similarity(target["embedding"], company["embedding"])
        similarities.append((company["symbol"], similarity))

    similarities.sort(key=lambda x: x[1], reverse=True)
    print(f"Top {top_n} similar companies to {symbol}:")
    for sym, sim_score in similarities[:top_n]:
        print(f"{sym}: Similarity {sim_score:.4f}")

# Example Usage:
find_similar("AAPL", top_n=3)
# Out:
# Loaded 10 existing company descriptions.
# Description for AAPL already exists, skipping.
# Description for MSFT already exists, skipping.
# Description for GOOGL already exists, skipping.
# Description for AMZN already exists, skipping.
# Description for TSLA already exists, skipping.
# Description for NVDA already exists, skipping.
# Description for META already exists, skipping.
# Description for NFLX already exists, skipping.
# Description for INTC already exists, skipping.
# Description for AMD already exists, skipping.
#
# Loading embedding model...
# Embedding model loaded.
#
# Embedding description for AAPL...
# Embedding description for MSFT...
# Embedding description for GOOGL...
# Embedding description for AMZN...
# Embedding description for TSLA...
# Embedding description for NVDA...
# Embedding description for META...
# Embedding description for NFLX...
# Embedding description for INTC...
# Embedding description for AMD...
#
# Saved embeddings for 10 companies to company_embeddings.json.
#
#
# Finding top 3 companies similar to AAPL...
#
# Top 3 similar companies to AAPL:
# MSFT: Similarity 0.6169
# INTC: Similarity 0.5722
# GOOGL: Similarity 0.4572
